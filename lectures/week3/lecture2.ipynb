# %%
import pandas as pd

# %%
df = pd.read_csv('../../AfricaCupofNationsMatches.csv')
df.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %%
wanted = df[['HomeTeam','AwayTeam','HomeTeamGoals','AwayTeamGoals']]
wanted.head(5)
# Out:
#     HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0     Sudan           Egypt            1.0            2.0
# 1  Ethiopia    South Africa            NaN            NaN
# 2     Egypt        Ethiopia            4.0            0.0
# 3      Egypt       Ethiopia            4.0            0.0
# 4     Sudan        Ethiopia            1.0            0.0

# %%
#selecting rows where Egypt appears
egypt= df[(df['HomeTeam']=='Egypt')|(df['AwayTeam']=='Egypt')]
egypt.head(5)
# Out:
#     Year      Date  Time    HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN      Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN      Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN      Egypt     Uganda            2.0            1.0
# 9   1962  21-Jan-62   NaN  Ethiopia       Egypt            4.0            2.0
# 13  1963  24-Nov-63   NaN      Egypt    Nigeria            6.0            3.0
#
#                Stage    SpecialWinConditions                 Stadium  \
# 3   Final Tournament                     NaN   Prince Farouk Stadium
# 5   Final Tournament                     NaN   Prince Farouk Stadium
# 7         Semifinals                     NaN  Hailé Sélassié Stadium
# 9              Final   win after extra time   Hailé Sélassié Stadium
# 13           Group B                     NaN   Kumasi Sports Stadium
#
#             City  Attendance
# 3          Cairo     30000.0
# ...

# %%
#Counting the number of rows and columns
df.shape
# Out:
# (622, 12)

# %%
missing_attendance=df[df['Attendance'].isna()]
missing_attendance.head(5)
# Out:
#     Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 1   1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 8   1962  20-Jan-62   NaN   Tunisia          Uganda            3.0
# 9   1962  21-Jan-62   NaN  Ethiopia           Egypt            4.0
# 10  1963  24-Nov-63   NaN     Ghana         Tunisia            1.0
# 11  1963  26-Nov-63   NaN     Ghana        Ethiopia            2.0
#
#     AwayTeamGoals              Stage  \
# 1             NaN         Semifinals
# 8             0.0  Third place match
# 9             2.0              Final
# 10            1.0            Group A
# 11            0.0            Group A
#
#                                  SpecialWinConditions                 Stadium  \
# 1   Ethiopia  wins due to disqualification of othe...                     NaN
# 8                                                 NaN  Hailé Sélassié Stadium
# 9                               win after extra time   Hailé Sélassié Stadium
# ...

# %%
#HomeTeamGoals between 3 qnd 6
goals_df = df[df['HomeTeamGoals'].between(3, 6)]
goals_df.head(5)
# Out:
#    Year      Date  Time    HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 2  1957  16-Feb-57   NaN     Egypt    Ethiopia            4.0            0.0
# 3  1959  22-May-59   NaN      Egypt   Ethiopia            4.0            0.0
# 6  1962  14-Jan-62   NaN  Ethiopia     Tunisia            4.0            2.0
# 8  1962  20-Jan-62   NaN   Tunisia      Uganda            3.0            0.0
# 9  1962  21-Jan-62   NaN  Ethiopia       Egypt            4.0            2.0
#
#                Stage    SpecialWinConditions                 Stadium  \
# 2              Final                     NaN       Municipal Stadium
# 3   Final Tournament                     NaN   Prince Farouk Stadium
# 6         Semifinals                     NaN  Hailé Sélassié Stadium
# 8  Third place match                     NaN  Hailé Sélassié Stadium
# 9              Final   win after extra time   Hailé Sélassié Stadium
#
#            City  Attendance
# 2      Khartoum     30000.0
# 3         Cairo     30000.0
# ...

# %%
loc_test=goals_df.loc[0:5,['Year','HomeTeam']]
loc_test
# Out:
#    Year HomeTeam
# 2  1957   Egypt
# 3  1959    Egypt

# %%
loc_test1=goals_df.iloc[0:5]
loc_test1
# Out:
#    Year      Date  Time    HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 2  1957  16-Feb-57   NaN     Egypt    Ethiopia            4.0            0.0
# 3  1959  22-May-59   NaN      Egypt   Ethiopia            4.0            0.0
# 6  1962  14-Jan-62   NaN  Ethiopia     Tunisia            4.0            2.0
# 8  1962  20-Jan-62   NaN   Tunisia      Uganda            3.0            0.0
# 9  1962  21-Jan-62   NaN  Ethiopia       Egypt            4.0            2.0
#
#                Stage    SpecialWinConditions                 Stadium  \
# 2              Final                     NaN       Municipal Stadium
# 3   Final Tournament                     NaN   Prince Farouk Stadium
# 6         Semifinals                     NaN  Hailé Sélassié Stadium
# 8  Third place match                     NaN  Hailé Sélassié Stadium
# 9              Final   win after extra time   Hailé Sélassié Stadium
#
#            City  Attendance
# 2      Khartoum     30000.0
# 3         Cairo     30000.0
# ...

# %%
#Accessing single values
year2=goals_df.iat[3,goals_df.columns.get_loc('HomeTeamGoals')]
print(year2)
# Out:
# 3.0

# %%
before_goals=df.iat[2,df.columns.get_loc('HomeTeamGoals')]
print(before_goals)
# Out:
# 4.0

# %%
#Change away team goals in third row to 10
df.iat[2,df.columns.get_loc('HomeTeamGoals')]=10
new_goals=df.iat[2,df.columns.get_loc('HomeTeamGoals')]
print(new_goals)
# Out:
# 10.0

# %%
#Sorting the dataframe by HomTeam in ascending order
df.sort_values(by=['HomeTeam'],inplace=True)
df.head(5)
# Out:
#      Year                         Date   Time   HomeTeam  AwayTeam  \
# 210  1990                      8-Mar-90    NaN  Algeria      Egypt
# 546  2017  19 January 2017 (2017-01-19)  17:00  Algeria    Tunisia
# 150  1982                     10-Mar-82    NaN  Algeria    Nigeria
# 148  1982                      7-Mar-82    NaN  Algeria     Zambia
# 611  2019      7 July 2019 (2019-07-07)  21:00  Algeria     Guinea
#
#      HomeTeamGoals  AwayTeamGoals        Stage SpecialWinConditions  \
# 210            2.0            0.0      Group A                  NaN
# 546            1.0            2.0      Group B                  NaN
# 150            2.0            1.0      Group B                  NaN
# 148            1.0            0.0      Group B                  NaN
# 611            3.0            0.0  Round of 16                  NaN
#
#                   Stadium          City  Attendance
# 210  Stade 5 Juillet 1962       Algiers     86000.0
# ...

# %%
#Sorting by HomeTeamScores in descending order
df.sort_values(by=['HomeTeamGoals'],inplace=True,ascending=False)
df.head(5)
# Out:
#      Year      Date   Time       HomeTeam       AwayTeam  HomeTeamGoals  \
# 13   1963  24-Nov-63    NaN         Egypt        Nigeria            6.0
# 46   1970  10-Feb-70    NaN  Ivory Coast        Ethiopia            6.0
# 464  2008  26-Jan-08  17:00     Cameroon          Zambia            5.0
# 72   1972   4-Mar-72    NaN     Cameroon           Zaire            5.0
# 270  1996  20-Jan-96    NaN       Zambia    Burkina Faso            5.0
#
#      AwayTeamGoals              Stage SpecialWinConditions  \
# 13             3.0            Group B                  NaN
# 46             1.0            Group A                  NaN
# 464            1.0            Group C                  NaN
# 72             2.0  Third place match                  NaN
# 270            1.0            Group B                  NaN
#
#                    Stadium           City  Attendance
# 13   Kumasi Sports Stadium         Kumasi         NaN
# 46       Municipal Stadium       Khartoum      9770.0
# ...

# %%
#Gettin list from dataframe column headers
df.columns
# Out:
# Index(['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %%
#Appending a column to the data frame
df['AppendedColumn']=None
df.head(5)
# Out:
#      Year      Date   Time       HomeTeam       AwayTeam  HomeTeamGoals  \
# 13   1963  24-Nov-63    NaN         Egypt        Nigeria            6.0
# 46   1970  10-Feb-70    NaN  Ivory Coast        Ethiopia            6.0
# 464  2008  26-Jan-08  17:00     Cameroon          Zambia            5.0
# 72   1972   4-Mar-72    NaN     Cameroon           Zaire            5.0
# 270  1996  20-Jan-96    NaN       Zambia    Burkina Faso            5.0
#
#      AwayTeamGoals              Stage SpecialWinConditions  \
# 13             3.0            Group B                  NaN
# 46             1.0            Group A                  NaN
# 464            1.0            Group C                  NaN
# 72             2.0  Third place match                  NaN
# 270            1.0            Group B                  NaN
#
#                    Stadium           City  Attendance AppendedColumn
# 13   Kumasi Sports Stadium         Kumasi         NaN           None
# ...

# %%
#Adding two rows to the dataframe
df.append(ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15076\471901920.py in ?()
#       1 #Adding two rows to the dataframe
# ----> 2 df.append()
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
